# %% [markdown]
# # Lab 1

# %% [markdown]
# this is my first lab

# %%
import pandas as pd

covid_data = pd.read_csv('s3://ia340-2025-fall-mt-4427/data.csv') #load data from the s3 csv

covid_data.head() #show the top 5 rows
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# 3  11/12/2020   11     12  2020     63      10             Afghanistan    AF
# 4  10/12/2020   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# ...

# %%
mining_data = pd.read_csv('s3://ia340-2025-fall-mt-4427/BLM_Natl_MLRS_Mining_Claims_-_Not_Closed.csv') #load other dataset

mining_data.head()
# Out:
#    OBJECTID                  ID CSE_NAME      STAGE_ID    BLM_PROD  \
# 0         1  803391412212129792   WR 195  8.033913e+17  Lode Claim
# 1         2  803392270358429696   WR 196  8.033922e+17  Lode Claim
# 2         3  803393529421299712   WR 198  8.033934e+17  Lode Claim
# 3         4  803394369225912320   WR 199  8.033942e+17  Lode Claim
# 4         5  803394873595121664   WR 200  8.033947e+17  Lode Claim
#
#    CSE_TYPE_NR       CSE_NR LEG_CSE_NR               SF_ID CSE_DISP  SRC  \
# 0       384101  NV105216280        NaN  a02t0000006LcZyAAK   Active  LLD
# 1       384101  NV105216281        NaN  a02t0000006LcZzAAK   Active  LLD
# 2       384101  NV105216283        NaN  a02t0000006Lca1AAC   Active  LLD
# 3       384101  NV105216284        NaN  a02t0000006Lca2AAC   Active  LLD
# 4       384101  NV105216457        NaN  a02t0000006Lca3AAC   Active  LLD
#
#                                                 QLTY  \
# 0  8: \n18 sections retrieved\n240 intersected fe...
# ...
